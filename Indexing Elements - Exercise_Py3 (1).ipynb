# %% [markdown]
# ## Indexing Elements

# %% [markdown]
# Extract the letter 'B' from "Bingo!".

# %%
a = "Bingo"

# %%
a.index("B")
# Out:
# 0

# %%
'Bingo'[0]
# Out:
# 'B'

# %% [markdown]
# Extract the letter "u" from "Constitution".

# %%
b = "Constitution"

# %%
b.index("u")
# Out:
# 7

# %%
'Constitution'[7]
# Out:
# 'u'
